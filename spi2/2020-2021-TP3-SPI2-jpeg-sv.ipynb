# %% [markdown]
# # Frequency Domain
# SPI2 Basics on Image processing
#
# Ecole Centrale Nantes
#
# Diana Mateus

# %% [markdown]
# Participant: Cheng XIANG

# %% [markdown]
# ## 0. Preparation
#
# ### 0.1 Import the required modules

# %%
from scipy import ndimage
import matplotlib.pyplot as plt
import numpy as np
import os
import skimage.io as io
from skimage.transform import resize

# %% [markdown]
# ### 0.2 Define the main image folder
# Make sure the subsequent parts of this notebook refer to this definition IMDIR. **When evaluating your notebook I should only need to change the path here** to run the entire notebook.

# %%
IMDIR = "./images/h"
print(os.listdir(IMDIR))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-253-107e918c4a91> in <module>
#       1 IMDIR = "./images/h"
# ----> 2 print(os.listdir(IMDIR))
#       3
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './images/h'

# %% [markdown]
# ### 0.2 Read and display the images
# Check that you can read and display all the provided images. Do not include this cell, the code nor its ouput in the final report

# %%
width=20
height=15
plt.rcParams['figure.figsize'] = [width, height]
            
fig=plt.figure()

im_counter = 1
for root, dirnames, filenames in os.walk(IMDIR):
    for filename in filenames:
        f = os.path.join(root, filename)
        
        #filter only image files with the following format
        if f.endswith(('.png', '.jpg', '.jpeg','.JPG', '.tif', '.gif')):
            
            # print the paths to current filename if nothing is being found
            # print(filename)
            
            # read the image 
            im = io.imread(f,as_gray=True)
            im = resize(im,(100,100),mode='constant')

            # display it
            plt.subplot(5,7,im_counter)
            plt.imshow(im, cmap='gray')
            plt.title(filename)
            plt.axis('off')
            im_counter +=1 


plt.show()

# %% [markdown]
# ## 1. The Discrete Fourier Transform

# %% [markdown]
# In this exercise we will compute and visualize a DFT using numpy's fft functions:
# - ```np.fft.fft2```: computes the two-dimensional FFT of an image.
# - ```np.fft.fftshift```: center the frecuencies in the middle of the image
# - ```np.fft.ifftshift```: reverses the centering
# - ```np.fft.ifft2```: inverse fourier transform
# - ```np.real```: takes the real components of a complex number
# - ```np.abs```: recovers the magnitude of a complex number
# - ```np.angle```: recovers the phase of a complex number
# - ```np.log```: computes the logarithm
#
# The following code uses the above functions applied to the provided images, and shows
#
# **a)** the original image
#
# **b)** the magnitude of its fft (scaled logarithmically)
#
# **c)** the magnitude of its **centered(shifted)** Discrete Fourier transform fft (scaled logarithmically)
#
# **c)** the inverse fft of the above transformed image (all the steps shouls be reversed)
#
# **d) For each image explain how to interpret the FFT images**

# %% [markdown]
# # IMAGES IN FOURIER FOLDER

# %%
SUBDIR = IMDIR 


for root, dirnames, filenames in os.walk(SUBDIR):
    # print path to all filenames.
    for filename in filenames:
        f = os.path.join(root, filename)
        if f.endswith(('.png', '.jpg', '.jpeg','.JPG', '.tif', '.gif')):
            print(f)
            im = io.imread(f,as_gray=True)
            #im = resize(im,(100,100),mode='constant') #Uncomment this line if it is too slow
    
            
            # TO EXPLAIN BY STUDENTS
            im_fft = np.fft.fft2(im)      #computes the two-dimensional FFT of an image.
            im_fft_shifted=np.fft.fftshift(im_fft) #  center the frecuencies in the middle of the image
            print(np.shape(im_fft_shifted))   #get the shape
            im_fft_shifted1=im_fft_shifted[:,:] 
            print(np.shape(im_fft_shifted1))  #get the shape           
            im_recon = np.real(np.fft.ifft2(np.fft.ifftshift(im_fft_shifted1))) #reverses the centering and inverse the furier transform and takes the real components 
            # END TO EXPLAIN BY STUDENTS
            
            
            fig=plt.figure(figsize=(16, 18))

            plt.subplot(141)
            plt.title('Original image')
            plt.imshow(im)
            plt.gray()
            plt.axis('off')

            
            plt.subplot(142)
            plt.title('log FFT ')
            plt.imshow(np.log(np.abs(im_fft)))
            plt.gray()
            plt.axis('off')
                        
            plt.subplot(143)
            plt.title('log shift FFT ')
            plt.imshow(np.log(np.abs(im_fft_shifted)))
            plt.gray()
            plt.axis('off')

            
            plt.subplot(144)
            plt.title('Reconstructed image')
            plt.imshow(im_recon)
            plt.gray()
            plt.axis('off')
            
            plt.show()

# %% [markdown]
# ##  2. PROJECT JPEG
#
# **Introduction**
#
# The jpeg compression follows several steps
#
# **i)** Convert images from RGB to YIQ color space
#
# **ii)** Reduce the size (to half) of the I and Q channels
#
# **iii)** An image is first subdivided in 8x8 subblocks (assuming the original image has sides whose length is a multiple of 8, if it is not the case just resize it).
#
# **iv)** A frequency transformation is computed for each block (computed with a discrete cosine transform DCT II )
# ```
# fftpack.dct(fftpack.dct(im.T, norm='ortho').T, norm='ortho')
# ```
# **v)** The DCT results are then divided by the elements of the the quantization matrices given in ```quantization_table```. The resulting values are then rounded and stored as integers. **Hint:** use the functions  ```round()```, ```astype(np.int32)```
#
# **vi)** The result of quantization (which should have many zeros) is then compressed Run Lenght Coding and Huffman coding to reduce the size. The compressed values are saved together with the quantization table. #won't do
#
# **vii)** The reconstruction of the image implies inverting the encoding, the quantization and the dct.

# %% [markdown]
# **Instructions**
#
# - This project is individual! This means both the code and report should be original and different for each of you. The 0 grade will apply for any attempt to break this rule.
#
# - You are expected to return both the jupyter notebook along with a report explaining the method and the results of the jpeg compression on SEVERAL images.
#
#
# - You are **ONLY** allowed to use:
#     - any ``numpy`` and ``matplotlib`` functions
#     - ``io.imread`` to read the images
#     - the provided functions to compute the ``dct``
#     - the provided functions to compute the quantization matrix ```quantization_table```.
#     - other functions from ``skimage`` are not needed!!! I will tolerate them only in the case you completely explain in the report (with descriptions and equations)  what this functions do.
#
#
# - If you use code from an external source, this source should be cited. Failinig to do so, also leads to a grade of 0.
#
#
# - The first cell of the notebook must start with the definition of the ```filename``` variable, which especifies the path of the image that will be compressed. To test your code on other images, I will only change this line. The code should run adapting to any input image.
#
#
# - Implement all the jpeg compression steps (i-v) . Do **NOT** implement step vi) Run Lenght Code and Huffman coding
#
#
# - Create **one function for each step**. Demonstrate the results of each step by calling each function: Show with images or graphs how the input image/list/data looks like before and after applying that function.
#
#
# - Implement the inverse steps, to go from the quantized dct values to the reconstructed images. Again use one function per step, and illustrate its results
#
#
# - Create a global jpegCompress function englobing steps i-v and a jpegDecompress function englobin steps in vii)
#
#
# - Call the jpegCompress and jpeg Decompress function on several images: e.g. before and after applying a gaussian filter, before and after downsizing the image, on images with high or low frequency content. Compare the images (e.g. by computing their differences). Write some comments for every experiment you try.
#
#
# - Compare how the frequency representation of the original and the compressed images, look at the spectrum magnitude and phase. You may also want to compare the histogram of the frequency components.
#
# **BONUS** Replace the given DCT function by your own basis implementation. Explain any difference.

# %%
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt
import skimage.transform as skt
from PIL import Image
import os

# %%
filename = "images/Fourier/zebra-wall.png"
im = io.imread(filename)
im = (im/255).astype(float) #To be sure is always between 0 and 1 after this cell


print(im.shape)
print(im.min(),im.max())

#Resize small first to debug
h = 128
w = 128

#The original function isn't defined, so I import the skimage.transform to resize the original picture
#If I use np.resize(im,(h,2)), the output will be one-dimensional, which is not the desired output
im1 = skt.resize(im,(h,w),mode='constant')*255 #This function will put the intensitites between 0 and 1 -> multiply by 255 when needed

print(im1.shape)
print(im1.min(),im1.max())
plt.imshow(np.uint8(im1))
# Out:
# (346, 518, 3)
# 0.0196078431372549 1.0
# (128, 128, 3)
# 8.207520644992085 252.93893847647118

# %%
#ATTENTION The quatization table assumes the original image intensities before the dct are between 0 and 255


from scipy import fftpack

def dct_2d(im):
    return fftpack.dct(fftpack.dct(im.T, norm='ortho').T, norm='ortho')

def idct_2d(im):
    return fftpack.idct(fftpack.idct(im.T, norm='ortho').T, norm='ortho')

def quantization_table(component='lum'):
    # Quantization Table for: Photoshop 
    # (http://www.impulseadventure.com/photo/jpeg-quantization.html)
    if component == 'lum':
        q = np.array([[2, 2, 2, 2, 3, 4, 5, 6],
                      [2, 2, 2, 2, 3, 4, 5, 6],
                      [2, 2, 2, 2, 4, 5, 7, 9],
                      [2, 2, 2, 4, 5, 7, 9, 12],
                      [3, 3, 4, 5, 8, 10, 12, 12],
                      [4, 4, 5, 7, 10, 12, 12, 12],
                      [5, 5, 7, 9, 12, 12, 12, 12],
                      [6, 6, 9, 12, 12, 12, 12, 12]])
    elif component == 'chrom':
        q = np.array([[3, 3, 5, 9, 13, 15, 15, 15],
                      [3, 4, 6, 11, 14, 12, 12, 12],
                      [5, 6, 9, 14, 12, 12, 12, 12],
                      [9, 11, 14, 12, 12, 12, 12, 12],
                      [13, 14, 12, 12, 12, 12, 12, 12],
                      [15, 12, 12, 12, 12, 12, 12, 12],
                      [15, 12, 12, 12, 12, 12, 12, 12],
                      [15, 12, 12, 12, 12, 12, 12, 12]])
    else:
        raise ValueError((
            "component should be either 'lum' or 'chrom', "
            "but '{comp}' was found").format(comp=component))

    return q

# %%
# transfer from rgb to yiq function
def rgb2yiq(img):
    yiq_from_rgb = np.array([[0.299, 0.587, 0.114],
                             [0.5959, -0.2746, -0.3213],
                             [0.2115, -0.5227, 0.3112]])
    yiq = np.dot(img[...,:3],yiq_from_rgb)
    #yiq=np.where(yiq < 0, 0, yiq)
    #yiq=np.where(yiq > 1, 1, yiq)
    return yiq

# %%
im_yiq = rgb2yiq(im1/255)
plt.imshow(im_yiq)
plt.axis('off')
print("The image shape of yiq image is:",im_yiq.shape)
print("The min and max number of yiq image is:",im_yiq.min(),im_yiq.max())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image shape of yiq image is: (128, 128, 3)
# The min and max number of yiq image is: -0.19187868236306727 1.0821252904224894

# %%
# reduce the I,Q channel to half function
def reduceIQ(img):
    for i in range(h):
        for j in range(w):
            img[i,j,1]=img[i,j,1]/2
            img[i,j,2]=img[i,j,2]/2
    return img

# %%
im_yiq_reduced=reduceIQ(im_yiq)
plt.imshow(im_yiq_reduced)
plt.axis('off')
print("The image shape of reduced yiq image is:",im_yiq_reduced.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image shape of reduced yiq image is: (128, 128, 3)

# %%
plt.subplot(1, 3, 1)
plt.title('original')
plt.imshow(np.uint8(im1))
plt.axis('off')
print(im1.shape)
print(im1.min(),im1.max())

plt.subplot(1, 3, 2)
plt.title('YIQ')
plt.imshow(im_yiq)
plt.axis('off')
print(im_yiq.shape)
print(im_yiq.min(),im_yiq.max())

plt.subplot(1, 3, 3)
plt.title('Reduced YIQ')
plt.imshow(im_yiq_reduced)
plt.axis('off')
print(im_yiq_reduced.shape)
print(im_yiq_reduced.min(),im_yiq_reduced.max())

#os.mkdir("F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images")  # creat a new file to store the cropped images
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (128, 128, 3)
# 8.207520644992085 252.93893847647118
# (128, 128, 3)
# -0.09593934118153363 1.0821252904224894
# (128, 128, 3)
# -0.09593934118153363 1.0821252904224894

# %%
# subdivided in 8x8 subblocks
def subdivided8x8(img):
    im=np.zeros((8,8,3))
    for i in range(int(h/8)):  # 0-15
        for j in range(int(w/8)):  # 0-15
            im = img[i*8:(i+1)*8, j*8:(j+1)*8, :]
            io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
    return im

# %%
img_divided=subdivided8x8(im_yiq_reduced)
print(img_divided.shape)
print(img_divided.min(),img_divided.max())
# Out:
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05352049137402345, 0.6728184388147886]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06066475261640102, 0.7391999317325526]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07462690350386492, 0.7846028470863776]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07973610844346868, 0.8375068217198537]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.08377773830617533, 0.9152195566261179]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07014981155126895, 0.7671856866175294]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07969152605563498, 0.8514666746618369]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.07848453852876515, 0.8545580482084384]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08944231298673391, 0.9293045311284804]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08905555919175073, 0.9284031376711948]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07912499253422217, 0.8444056120279821]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05446983592181167, 0.6252713904862834]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05912916163028345, 0.7196447207420882]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06063963289637671, 0.6940386870525541]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08574439392308458, 0.9068068008439432]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim0_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06077241472637507, 0.7168368010231698]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05529392629784305, 0.6799252020929059]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.061806984469734184, 0.7477540706586263]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07201664714145894, 0.7737569781486636]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08297441995371538, 0.8902122445585986]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0781774546006821, 0.8650088599754213]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08021752659007796, 0.8642875397879162]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0848637751107692, 0.8881678130744561]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_7.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0863495567579539, 0.9243483958216123]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08805762190003238, 0.9403494843521668]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08424714589878998, 0.892673434055797]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07809254766393822, 0.8574100486531266]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.055720420064615576, 0.6581139901285031]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06164048721836608, 0.7234245930243073]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06386230700759261, 0.7360930661666905]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08925669527091928, 0.9140292843236484]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim1_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07228896500863928, 0.7576197803084327]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06880537839889408, 0.7983937485314951]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06321594929610545, 0.7448694720340236]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06354920632414217, 0.7012512799888193]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0771492148041088, 0.8719195972678986]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08375621849527679, 0.8845161638747162]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08432108693266695, 0.91173624305009]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0785260960722869, 0.8448735036113779]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.08294209248293619, 0.8936865678970194]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.09335823032263864, 0.9833764532168352]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08394658979251633, 0.9103222293821296]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07918756336013286, 0.9043278719930858]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05891424908495056, 0.6871077356646778]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0658149404602745, 0.7664154980696425]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06945528786513042, 0.7763523600439933]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08994670952178291, 0.9328951177181568]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim2_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07597409893215895, 0.8212443885143196]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0724963217898679, 0.8327924326042779]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06423011220055636, 0.7469772656175779]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0497472760842029, 0.6245716674243309]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07026508260483325, 0.8403746164308411]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.088860087930785, 0.9171945935272104]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.062480067109674825, 0.7259076513414823]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08805678175626125, 0.977255068303738]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.0846763741601898, 0.9072484484788621]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0930916430875402, 0.9801985747371618]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08593733455403149, 0.936165326638513]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07986274163715057, 0.8748394101442278]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05877989312614093, 0.707737696672198]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0729906064007892, 0.8366066425204911]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07116636561846315, 0.7921076200466396]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08939659546627442, 0.9131881654030609]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim3_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05899515428601962, 0.6950560558655712]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.0694063100217728, 0.8298770799420905]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06771365526311685, 0.7793974046433279]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05103413200532268, 0.6227740096438736]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07675215936918162, 0.8730449399980442]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05593751666346884, 0.6410432459862769]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.04071185912203657, 0.6782336295236258]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.041965370453605835, 0.6423544414066591]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_7.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0699096480926534, 0.766883753533973]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.09377559247419202, 0.9898131431746253]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07466014167817796, 0.8269062367136424]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08581076828817703, 0.9375132020717292]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06655595643565834, 0.7848243651259095]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0639986351295118, 0.8043522947808124]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07113296178409234, 0.7878778222266746]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.09075429869541204, 0.926528758058012]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim4_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05182158926571503, 0.6135268066475246]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.04755318347880477, 0.704392661496523]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0691350796321363, 0.8480345007994458]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05828923949726396, 0.662292895934796]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.07268105175627904, 0.8329526787520696]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.053558756720730696, 0.5651530828442095]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.03645828362590803, 0.6687090081619896]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.039110517569497086, 0.48677862103679226]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_7.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06929816432813585, 0.8138505412391295]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.09328519869417587, 0.9857181083157176]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07921126173051825, 0.8584540869216577]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08244392200992687, 0.9284640972495353]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07348296126466422, 0.8411129032528208]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07065105957429718, 0.7870325881061621]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07550617352744028, 0.8066464928658725]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08656877307455675, 0.8936346276303422]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim5_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05323208124809713, 0.6377916821347208]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05637096910092657, 0.716662882152446]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0679453056478768, 0.7922221405582144]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05497881901027557, 0.5099489320967685]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.076412423738446, 0.7717873332466162]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05555531926761856, 0.5943573781348495]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0294349702591822, 0.5471555535708548]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0466110216301697, 0.6076228696715371]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.07333027249181756, 0.8146799432164656]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.09452308928708114, 0.9951320255429026]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08095081806489547, 0.8605191403939169]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07805558083470987, 0.8794093940524701]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07090064875650257, 0.8360562757573371]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0652118121066916, 0.77075335866026]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06758644406478102, 0.7642024342632456]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08533921374918114, 0.9038495398514581]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim6_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05319688612089685, 0.6469841276912656]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05740523003061581, 0.720490982187628]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06518541580870704, 0.7641355853748804]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_2.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08423559665671224, 0.8457979604793915]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.05604850688966312, 0.7258655836006427]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.03550567791364043, 0.6229713906409178]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.02735359553235329, 0.43319736987739]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim7_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0462284130275563, 0.5124274072119459]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08123533133402364, 0.9377593224903674]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06870696738391253, 0.8228867420853194]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.04899358078223065, 0.6951075596298628]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.058427798336861195, 0.7788712347696896]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06606313505000792, 0.792615711146192]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05354523698910234, 0.7205766888201303]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.059276676144017076, 0.8296692222691057]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim13_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05152100265126763, 0.6688784144894118]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0312545323827194, 0.43341646722523]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.057188520420196606, 0.6326355186751986]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.09593934118153363, 1.0769948678248347]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.08236306683401148, 0.9430740142815641]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.07129027820198269, 0.9199353960057731]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.08010447583813485, 0.9013182153358625]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07067808379342444, 0.8356383197729094]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_7.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06591237745686526, 0.7329385969285314]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07495148093739176, 0.9056679138035415]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06344059757165431, 0.7900414539389305]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05022209459924008, 0.7210474204186506]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.056319555589662736, 0.8081186883691226]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05933546463390419, 0.7617707484663447]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05381405438265171, 0.7292934946921843]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05329710970990426, 0.803258981197017]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim14_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.050309518214060184, 0.6546609099896741]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_0.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.028637890534186194, 0.3500218910026799]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_1.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.03934284838767509, 0.4683340768858525]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-0.07583512608581938, 0.8943928003538162]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_3.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05057590681521361, 0.5791242499367211]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_4.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.0679875820846279, 0.8306590257954509]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_5.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.07741696988886107, 0.8895189973554669]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_6.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06856350839871628, 0.8027799543062445]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_7.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.057626433273428285, 0.6762280150067701]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_8.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06470728010429394, 0.8768913438014021]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_9.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.06560370079985123, 0.797487322310151]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_10.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05343768515166998, 0.7587774866174655]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_11.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05673059314123303, 0.8558546000278594]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_12.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05684913688892774, 0.7911338777477996]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_13.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.046692204180347925, 0.6833486171245118]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_14.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.05458697760748567, 0.8195496152745334]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-293-fe02ab16de25>:7: UserWarning: F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim15_15.png is a low contrast image
#   io.imsave('F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim{}_{}.png'.format(i, j),im.astype(float))
# Lossy conversion from float64 to uint8. Range [-0.04578513618084317, 0.6575056656281222]. Convert image to uint8 prior to saving to suppress this warning.
# (8, 8, 3)
# -0.04578513618084317 0.6575056656281222

# %%
# show the sub divided images
im_counter=1
for i in range(int(h/8)):
    for j in range(int(w/8)):
        filename = "F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim"+str(i)+"_"+str(j)+".png"
        im = io.imread(filename)
        plt.subplot(16,16,im_counter)
        plt.imshow(im)
        plt.axis('off')
        im_counter +=1

# %%
# fft for sub images function
def fft4sub_img():     
    im_counter=1
    d = np.zeros((256, 8, 8, 3))
    for i in range(int(h/8)):
        for j in range(int(w/8)):
            filename = "F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim"+str(i)+"_"+str(j)+".png"
            im = io.imread(filename)
            im=im.astype(np.uint8)
            fft_img=dct_2d(im)
            plt.subplot(16,16,im_counter)            
            plt.imshow(fft_img)
            plt.axis('off')
            d[im_counter-1]=fft_img # store 8*8*3 sub image into a 4 dimentional matrix
            im_counter +=1
    return  d

# %%
d= fft4sub_img() 
print(d.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (256, 8, 8, 3)

# %%
print(d.shape[0])
# Out:
# 256

# %%
# quantilization function
def quantilization(dct):
    k = np.zeros((8, 8, 3))
    for i in range(dct.shape[0]):
        k[:, :, 0] = dct[:, :, 0]/quantization_table(component = 'lum')
        k[:, :, 1] = dct[:, :, 1]/quantization_table(component = 'chrom')
        k[:, :, 2] = dct[:, :, 2]/quantization_table(component = 'chrom')        
    return k

# %%
img_qua = quantilization(dct).astype(np.int32)

# %%
# inverse quantilization function
def i_quantilization(i_dct):
    k = np.zeros((8, 8, 3))
    for i in range(dct.shape[0]):
        k[:, :, 0] = dct[:, :, 0]*quantization_table(component = 'lum')
        k[:, :, 1] = dct[:, :, 1]*quantization_table(component = 'chrom')
        k[:, :, 2] = dct[:, :, 2]*quantization_table(component = 'chrom')        
    return k

# %%
img_iqua = i_quantilization(img_qua).astype(np.int32)

# %%
# ifft for sub images
def ifft4sub_img(dct):  
    i_d = np.zeros((256, 8, 8, 3))
    ifft_img=np.zeros((8, 8, 3))
    k=0
    for i in range(dct.shape[0]): #0-255
            ifft_img=idct_2d(dct[i])
            i_d[k] = ifft_img
            k=k+1
    return i_d

# %%
# assemble the images function
def i_subdivided8x8():
    im=np.zeros((h,w,3))
    for i in range(int(h/8)):  # 0-15
        for j in range(int(w/8)):  # 0-15
            filename = "F:\Python codes\SPI2\LAB3-PROJECT\images\Fourier\Sub_images\subim"+str(i)+"_"+str(j)+".png"
            sub_im = io.imread(filename)
            im[i*8:(i+1)*8, j*8:(j+1)*8, :]= sub_im
    return im.astype('uint8')

# %%
im_ass=i_subdivided8x8()
plt.subplot(1, 2, 1)
plt.imshow(im_ass)
#print(im_as.shape)
#print(im_as.min(),im_as.max())

plt.subplot(1, 2, 2)
plt.title('Reduced YIQ')
plt.imshow(im_yiq_reduced)
plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 127.5, 127.5, -0.5)

# %%
# double the I,Q channel 
def i_reduceIQ(img):
    for i in range(h):
        for j in range(w):
            img[i,j,1]=img[i,j,1]*2
            img[i,j,2]=img[i,j,2]*2
    return img

# %%
img_dob=i_reduceIQ(im_ass)
plt.imshow(im_ass)

# %%
# transfer from yiq to rgb function
def yiq2rgb(img):
    yiq = np.float32(img)
    print(yiq)
    rgb_from_yiq = np.array([[1, 0.956, 0.619],      
                             [1, -0.272, -0.647],
                             [1,-1.106,1.703]])
 
    rgb = np.dot(yiq[...,:3],rgb_from_yiq)
    return rgb                           # np.clip(rgb,0,1).astype(np.float32)

# %%
im_rgb = yiq2rgb(img_dob)
plt.imshow(im_rgb)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[165.  28.  96.]
#   [175.  24.  96.]
#   [200.  16.  96.]
#   ...
#   [220.  16.  96.]
#   [175.  28.  88.]
#   [ 80.  64.  84.]]
#
#  [[172.  24.  96.]
#   [192.  16.  96.]
#   [211.  12.  96.]
#   ...
#   [235.   8.  96.]
#   [191.  24.  88.]
#   [ 88.  60.  84.]]
#
#  [[166.  24.  92.]
#   [199.  16. 100.]
#   [211.  12.  96.]
#   ...
#   [229.   8.  96.]
#   [194.  20.  92.]
#   [ 93.  60.  84.]]
#
#  ...
#
#  [[ 66.  76.  80.]
#   [173.  72.  96.]
#   [196.  88.  96.]
#   ...
#   [202.  28.  84.]
#   [232.  24.  84.]
#   [228.  20.  88.]]
#
#  [[ 83.  76.  84.]
#   [199.  68. 100.]
#   [222.  68. 104.]
#   ...
#   [203.  32.  80.]
#   [230.  28.  84.]
#   [227.  24.  84.]]
#
#  [[ 94.  76.  84.]
#   [203.  60. 100.]
#   [224.  52. 108.]
#   ...
#   [194.  32.  80.]
#   [213.  28.  80.]
#   [210.  28.  80.]]]
